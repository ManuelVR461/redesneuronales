# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelVR461/redesneuronales/blob/master/ataquesadversarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import tensorflow as tf
import keras

# %%
from keras.applications.inception_v3 import InceptionV3,decode_predictions
from keras import backend as k

# %%
iv3 = InceptionV3()

# %%
print(iv3.summary());
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 149, 149, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 149, 149, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from keras.preprocessing import image

# %%
from google.colab import files
 
files.upload()
# Out:
#      <input type="file" id="files-cf5f8ab1-6e97-4119-99a5-689cd2770e87" name="files[]" multiple disabled />
#      <output id="result-cf5f8ab1-6e97-4119-99a5-689cd2770e87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cervezas.jpg to cervezas.jpg
# Saving gatitos.jpg to gatitos.jpg
# ...

# %%
#title Texto de título predeterminado
x = image.img_to_array(image.load_img("cervezas.jpg",target_size=(299,299)));

#Cambio de rango de (0 a 255) a (-1 a 1)
x /= 255
x -= 0.5
x*= 2
#print(x.shape); ->(299, 299, 3)

#hy que agregarle un tensor con 1 dimension adicional que hace referencia al tamaño del lote. osea numero de images
x = x.reshape(1, x.shape[0],x.shape[1],x.shape[2])

#print(x.shape); ->(1, 299, 299, 3)

print(x.shape);
# Out:
# (1, 299, 299, 3)

# %%
y = iv3.predict(x);

# %%
decode_predictions(y)
# Out:
# [[('n07932039', 'eggnog', 0.4657352),
#   ('n04131690', 'saltshaker', 0.18256629),
#   ('n04560804', 'water_jug', 0.055946987),
#   ('n02823750', 'beer_glass', 0.025910908),
#   ('n03950228', 'pitcher', 0.021998702)]]
