# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelVR461/redesneuronales/blob/master/regresionlineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston

# %%
#cargamos la libreria

boston = load_boston();

#print(boston.DESCR)

# %%
x = np.array(boston.data[:,5]);
y = np.array(boston.target);

plt.scatter(x,y,alpha=0.3);


x = np.array([np.ones(506),x]).T

b = np.linalg.inv(x.T @ x) @ x.T @ y; #minim de cuadrados ordinarios

plt.plot([4,9],[b[0]+b[1] * 4,b[0]+b[1]*9])
plt.show;

# %%
b
# Out:
# array([-34.67062078,   9.10210898])
